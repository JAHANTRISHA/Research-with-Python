# %% [markdown]
# <a href="https://colab.research.google.com/github/JAHANTRISHA/Research-with-Python/blob/main/Matplotlib_Seaborn/4_Matplotlib_and_Seaborn_for_Data_Science_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Upload: StudentsPerformance.csv and gym_membership.csv

# Load data
students = pd.read_csv('StudentsPerformance.csv')
gym = pd.read_csv('gym_membership.csv')

# %%
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %%
### Created by trisha
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
students = pd.read_csv('/content/drive/MyDrive/skillMorph/Class4/StudentsPerformance.csv')  # No header in raw CSV

# %% [markdown]
# ## **Understand the Data**

# %%
# Check data
print(students.head())
print(students.shape)  # How many rows and columns
print(students.columns.tolist())  # Column names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# (1000, 8)
# ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']

# %%
print("\nDataFrame Description:")
print(students.describe())
# Out:
# DataFrame Description:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Basic DataFrame information
print("\nDataFrame Info:")
print(students.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
# Display last 5 rows
print("\nLast 5 rows of the dataset:")
print(students.tail())
# Check data types
print("\nData Types:")
print(students.dtypes)
# Out:
# Last 5 rows of the dataset:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# Data Types:
# gender                         object
# race/ethnicity                 object
# ...

# %% [markdown]
# # **Line Graph**

# %%
# Simple line plot: First 10 math scores
plt.plot(students['math score'].head(10))  # X-axis auto (row numbers)

plt.title('Math Scores of First 10 Students')  # Title
plt.xlabel('Student Number')  # X label
plt.ylabel('Math Score')  # Y label
plt.show()  # Show plot

# %%
# Simple line plot: First 10 math scores
plt.plot(students['math score'].head(10))  # X-axis auto (row numbers)

plt.title('Math Scores of First 10 Students')  # Title
plt.xlabel('Student Number')  # X label
plt.ylabel('Math Score')  # Y label
plt.grid(True, which='both', linestyle="-", linewidth=0.7, alpha=0.7)
plt.savefig("/content/drive/MyDrive/skillMorph/Class4/math_score.png", dpi=300, bbox_inches="tight")
plt.show()  # Show plot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# First 10 math scores
scores = students['math score'].head(10)

# Create x-axis as 1 to 10
x = range(1, 11)   # or list(range(1, 11))

plt.plot(x, scores, marker='o')
plt.title('Math Scores of First 10 Students')
plt.xlabel('Student Number')
plt.ylabel('Math Score')
#plt.xticks(range(1, 11))
plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
# Count gender
gender_count = students['gender'].value_counts()

# Simple bar chart
plt.bar(['Female', 'Male'], gender_count.values)
plt.title('Gender Count')
plt.show()

# %%
# With color
plt.bar(['Female', 'Male'], gender_count.values, color=['pink', 'blue'])
plt.ylabel('Count')
plt.title('Students by Gender')
plt.show()

# %%
# Group by gender, average math score
avg_math = students.groupby('gender')['math score'].mean()

# Bar plot
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.bar(avg_math.index, avg_math.values)
plt.title('Average Math Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Math Score')
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
from pickle import FALSE
# Math vs Reading

plt.scatter(students['math score'], students['reading score'])
plt.grid(True)
plt.xlabel('Math')
plt.ylabel('Reading')
plt.title('Math vs Reading')
plt.show()

# %%
# Smaller sample for clarity
sample = students.head(100)
plt.scatter(sample['math score'], sample['reading score'], alpha=0.5)
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %% [markdown]
# # **Histogram**

# %%
# Math score distribution
plt.hist(students['math score'])
plt.title('Math Score Distribution')
plt.show()

# %%
# With more bins
plt.hist(students['math score'], bins=20, color='green')
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('Math Scores')
plt.show()

# %%
# Test preparation
test_prep = students['test preparation course'].value_counts()

plt.pie(test_prep.values, labels=['None', 'Completed'])
plt.title('Test Preparation')
plt.show()

# %%
# With percentages
plt.pie(test_prep.values, labels=['None', 'Completed'], autopct='%1.1f%%')
plt.title('Test Prep Status')
plt.show()

# %%
education_counts = students['parental level of education'].value_counts()
plt.pie(education_counts, labels=education_counts.index, autopct='%1.2f%%')
plt.title('Parental Education Levels')
plt.show()

# %% [markdown]
# # **Multiple Plots**

# %%
# Create 2x2 grid
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot 1: Histogram
axes[0, 0].hist(students['math score'], bins=15)
axes[0, 0].set_title('Math Score')

# Plot 2: Bar chart
students['gender'].value_counts().plot(kind='bar', ax=axes[0, 1])
axes[0, 1].set_title('Gender')

# Plot 3: Scatter
axes[1, 0].scatter(students['math score'][:50], students['reading score'][:50])
axes[1, 0].set_title('Math vs Reading')

# Plot 4: Line
axes[1, 1].plot(students['writing score'][:30])
axes[1, 1].set_title('Writing Scores')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Seaborn**

# %%
sns.histplot(students['math score'])
plt.title('Math Score with Seaborn')
plt.show()

# With KDE curve
sns.histplot(students['math score'], kde=True)
plt.show()

# %% [markdown]
# # **Box Plot**

# %%
# Gender vs Math Score
sns.boxplot(data=students, x='gender', y='math score')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Math by Gender')
plt.show()

# Lunch type effect
sns.boxplot(data=students, x='lunch', y='math score')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Math by Lunch Type')
plt.show()

# %% [markdown]
# # **Count Plot**

# %%
# Count by race/ethnicity
sns.countplot(data=students, x='race/ethnicity')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Race/Ethnicity Count')
plt.show()

# %%
# Count test prep
sns.countplot(data=students, x='test preparation course')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Test Prep Count')
plt.show()

# %% [markdown]
# # **Bar Plot with Average**

# %%
# Average math score by gender
sns.barplot(data=students, x='gender', y='math score')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Average Math Score by Gender')
plt.show()

# %%
# By parent education
sns.barplot(data=students, x='parental level of education', y='math score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Math score by gender
sns.kdeplot(data=students, x='math score', hue='gender')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Math Score by Gender')
plt.show()

# %% [markdown]
# # **Count Plot**

# %%
# Count by race/ethnicity
sns.countplot(data=students, x='race/ethnicity')
plt.title('Race/Ethnicity Count')
plt.show()

# Count test prep
sns.countplot(data=students, x='test preparation course')
plt.title('Test Prep Count')
plt.show()

# %% [markdown]
# # **Distribution Plots**

# %%
# Average math score by gender
sns.barplot(data=students, x='gender', y='math score')
plt.title('Average Math Score by Gender')
plt.show()

# By parent education
sns.barplot(data=students, x='parental level of education', y='math score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Heatmap**

# %%
# Correlation between scores
scores = students[['math score', 'reading score', 'writing score']]
correlation = scores.corr()
print(correlation)
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
# Simple heatmap
sns.heatmap(correlation)
plt.title('Score Correlations')
plt.show()

# %%
# With numbers
sns.heatmap(correlation, annot=True)
plt.title('Score Correlations')
plt.show()

# %% [markdown]
# # **Pairplot**

# %%
# Simple pairplot - just scores
score_data = students[['math score', 'reading score', 'writing score']]
sns.pairplot(score_data)
plt.show()

# %%
# With gender
score_gender = students[['math score', 'reading score', 'gender']]
sns.pairplot(score_gender,  hue='gender')
plt.show()

# %% [markdown]
# # **EDA Function**

# %%
def simple_eda(df):
    """Create 6 basic plots"""

    fig, axes = plt.subplots(2, 3, figsize=(12, 8))

    # 1. Math histogram
    axes[0, 0].hist(df['math score'], bins=20)
    axes[0, 0].set_title('Math Score')

    # 2. Gender count
    df['gender'].value_counts().plot(kind='bar', ax=axes[0, 1])
    axes[0, 1].set_title('Gender')

    # 3. Test prep pie
    test = df['test preparation course'].value_counts()
    axes[0, 2].pie(test.values, labels=['None', 'Completed'], autopct='%1.0f%%')
    axes[0, 2].set_title('Test Prep')

    # 4. Math vs Reading
    axes[1, 0].scatter(df['math score'], df['reading score'], alpha=0.3)
    axes[1, 0].set_title('Math vs Reading')

    # 5. Lunch effect
    lunch_avg = df.groupby('lunch')['math score'].mean()
    axes[1, 1].bar(lunch_avg.index, lunch_avg.values)
    axes[1, 1].set_title('Lunch Effect')

    # 6. Average scores
    avg = [df['math score'].mean(), df['reading score'].mean(), df['writing score'].mean()]
    axes[1, 2].bar(['Math', 'Reading', 'Writing'], avg)
    axes[1, 2].set_title('Average Scores')

    plt.tight_layout()
    plt.show()

# Run it
simple_eda(students)

# %%
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

gym = pd.read_csv('/content/drive/MyDrive/skillMorph/Class4/gym_membership.csv')

# %% [markdown]
# # **Gym Data Exploration**

# %%
# Basic gym plots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Age distribution
axes[0, 0].hist(gym['Age'], bins=20)
axes[0, 0].set_title('Age Distribution')

# Gender count
gym['gender'].value_counts().plot(kind='bar', ax=axes[0, 1])
axes[0, 1].set_title('Gender')

# Visits per week
axes[1, 0].hist(gym['visit_per_week'], bins=10)
axes[1, 0].set_title('Visits per Week')

# Personal training
gym['personal_training'].value_counts().plot(kind='pie', ax=axes[1, 1], autopct='%1.0f%%')
axes[1, 1].set_title('Personal Training')

plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Upload: gym_membership.csv

# Load data
gym = pd.read_csv('gym_membership.csv')

# %%
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

gym = pd.read_csv('/content/drive/MyDrive/skillMorph/Class4/gym_membership.csv')

# %%
# Gym data
print("\nGym Dataset:")
print(gym.head())
# Display last 5 rows
print("\nLast 5 rows of the dataset:")
print(gym.tail())
# Check data types
print("\nData Types:")
print(gym.dtypes)
print(gym.shape)
print(gym.columns.tolist())
# Out:
# Gym Dataset:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()

# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])

# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()
gym_membership = gym['abonoment_type'].value_counts()

plt.bar(['Standard', 'Premium'], gym_membership.values, color=['lightgreen', 'lightblue'])
plt.title('Gym Membership Types')
plt.show()

# %%
# Plot 1: Histogram
# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])
plt.hist(gym['avg_time_in_gym'], bins=20, color='skyblue')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Average Time in GYM')
plt.show()

# %%
# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])
from pickle import FALSE

plt.scatter(gym['Age'], gym['visit_per_week'])
plt.grid(True)
plt.xlabel('Age')
plt.ylabel('visits per week')
plt.title('Age vs Visits per week')
plt.show()

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')

# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')

# 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')
sns.boxplot(data=gym, x='gender', y='Age')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.title('Gender vs Age')
plt.show()

# %%
# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')
plt.figure(figsize=(20, 10))
sns.countplot(data=gym, x='days_per_week')
plt.grid(True, which="both", linestyle="--", linewidth=0.7, alpha=0.7)
plt.xticks(rotation=90)
plt.title('Days per week')
plt.show()

# %%
# 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')
sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')
plt.grid(True, which="both", linestyle="--", linewidth=.7, alpha=0.7)
plt.title('Average visits by membership type')
plt.show()
